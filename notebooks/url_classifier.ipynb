# %%
import advertools as adv
import pandas as pd
import os

# %%
crawl_df = pd.read_json("../output/crawl_output.jl", lines=True)
crawl_df
# Out:
#                                                     url  \
# 0                                       https://dev.to/
# 1                               https://dev.to/t/devops
# 2                                https://dev.to/t/react
# 3                           https://dev.to/t/opensource
# 4                           https://dev.to/t/javascript
# ...                                                 ...
# 2003                         https://dev.to/t/wikipedia
# 2004                             https://dev.to/rahxuls
# 2005                           https://dev.to/t/blogger
# 2006  https://dev.to/kallmanation/attracting-retaini...
# 2007                       https://dev.to/frontendfoxes
#
#                                                   title  \
# 0     DEV Community@@Navigation menu@@Search@@Search...
# 1     Devops - DEV Community@@Navigation menu@@Searc...
# 2     React - DEV Community@@Navigation menu@@Search...
# 3     Open Source - DEV Community@@Navigation menu@@...
# 4     JavaScript - DEV Community@@Navigation menu@@S...
# ...                                                 ...
# 2003  Wikipedia - DEV Community@@Navigation menu@@Se...
# 2004  Rahul - DEV Community@@Navigation menu@@Search...
# 2005  Blogger - DEV Community@@Navigation menu@@Sear...
# 2006  Attracting & Retaining in a Boring Industry - ...
# 2007  Front-End Foxes - DEV Community@@Navigation me...
#
#                                               meta_desc  \
# 0     A constructive and inclusive social network fo...
# 1                       devops content on DEV Community
# 2                        react content on DEV Community
# 3                   opensource content on DEV Community
# 4                   javascript content on DEV Community
# ...                                                 ...
# 2003                 wikipedia content on DEV Community
# 2004                         18, Hustler. Avid reader.
# 2005                   blogger content on DEV Community
# 2006  Photo by Siavash Ghanbari on Unsplash     I wo...
# 2007                                                NaN
#
#                                                viewport charset  \
# 0     width=device-width, initial-scale=1.0, viewpor...   utf-8
# 1     width=device-width, initial-scale=1.0, viewpor...   utf-8
# 2     width=device-width, initial-scale=1.0, viewpor...   utf-8
# 3     width=device-width, initial-scale=1.0, viewpor...   utf-8
# 4     width=device-width, initial-scale=1.0, viewpor...   utf-8
# ...                                                 ...     ...
# 2003  width=device-width, initial-scale=1.0, viewpor...   utf-8
# 2004  width=device-width, initial-scale=1.0, viewpor...   utf-8
# 2005  width=device-width, initial-scale=1.0, viewpor...   utf-8
# 2006  width=device-width, initial-scale=1.0, viewpor...   utf-8
# 2007  width=device-width, initial-scale=1.0, viewpor...   utf-8
#
#                                                      h1  \
# 0                                                 Posts
# 1     \n                #\n                devops\n ...
# 2          \n                React\n            @@Posts
# 3     \n                Open Source\n            @@P...
# 4     \n                JavaScript\n            @@Posts
# ...                                                 ...
# 2003  \n                #\n                wikipedia...
# 2004                                              Rahul
# 2005  \n                #\n                blogger\n...
# 2006  \n              Attracting & Retaining in a Bo...
# 2007                                    Front-End Foxes
#
#                                                      h2  \
# 0     DEV Community@@\n    DEV Community is a commun...
# 1     DEV Community@@\n        \n          ✨Git Bise...
# 2     DEV Community@@\n        \n          🤖 We aske...
# 3     DEV Community@@\n        \n          How to In...
# 4     DEV Community@@\n        \n          🤖 We aske...
# ...                                                 ...
# 2003  DEV Community@@\n        \n          Golang Wi...
# 2004  DEV Community@@\n        \n          My #chris...
# 2005  DEV Community@@\n        \n          Hyde\n   ...
# 2006  DEV Community@@\n  \n  \n  Tell the Stories of...
# 2007  DEV Community@@\n        \n          Join us a...
#
#                                                      h3  \
# 0     Popular Tags@@      Ready to launch your tech ...
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 2003                                                NaN
# 2004  Organizations@@GitHub Repositories@@Badges@@\n...
# 2005                                                NaN
# 2006  Sort discussion: @@GitHub Actions in Automatio...
# 2007                \n          Meet the team\n
#
#                                                      h4  \
# 0           trending guides/resources@@recently queried
# 1     submission guidelines@@tag moderators@@#discus...
# 2     submission guidelines@@about #react@@tag moder...
# 3     submission guidelines@@about #opensource@@tag ...
# 4     submission guidelines@@about #javascript@@tag ...
# ...                                                 ...
# 2003                                           #discuss
# 2004  LearnnHQ@@Fueler - Your Developer Portfolio@@L...
# 2005                                                NaN
# 2006                                                NaN
# 2007                                                NaN
#
#                                               canonical  ...  \
# 0                                       https://dev.to/  ...
# 1                               https://dev.to/t/devops  ...
# 2                                https://dev.to/t/react  ...
# 3                           https://dev.to/t/opensource  ...
# 4                           https://dev.to/t/javascript  ...
# ...                                                 ...  ...
# 2003                         https://dev.to/t/wikipedia  ...
# 2004                             https://dev.to/rahxuls  ...
# 2005                           https://dev.to/t/blogger  ...
# 2006  https://kallmanation.com/attracting-and-retain...  ...
# 2007                       https://dev.to/frontendfoxes  ...
#
#                                      jsonld_description  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 2003                                                NaN
# 2004                         18, Hustler. Avid reader.
# 2005                                                NaN
# 2006                                                NaN
# 2007  Front-End Foxes are women who want to learn fr...
#
#                   jsonld_email   h5 redirect_times redirect_ttl redirect_urls  \
# 0                          NaN  NaN            NaN          NaN           NaN
# 1                          NaN  NaN            NaN          NaN           NaN
# 2                          NaN  NaN            NaN          NaN           NaN
# 3                          NaN  NaN            NaN          NaN           NaN
# 4                          NaN  NaN            NaN          NaN           NaN
# ...                        ...  ...            ...          ...           ...
# 2003                       NaN  NaN            NaN          NaN           NaN
# 2004  gamerrahul1122@gmail.com  NaN            NaN          NaN           NaN
# 2005                       NaN  NaN            NaN          NaN           NaN
# 2006                       NaN  NaN            NaN          NaN           NaN
# 2007                       NaN  NaN            NaN          NaN           NaN
#
#      redirect_reasons og:title_1 resp_headers_set-cookie  \
# 0                 NaN        NaN                     NaN
# 1                 NaN        NaN                     NaN
# 2                 NaN        NaN                     NaN
# 3                 NaN        NaN                     NaN
# 4                 NaN        NaN                     NaN
# ...               ...        ...                     ...
# 2003              NaN        NaN                     NaN
# 2004              NaN        NaN                     NaN
# 2005              NaN        NaN                     NaN
# 2006              NaN        NaN                     NaN
# 2007              NaN        NaN                     NaN
#
#                                  request_headers_cookie
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 2003  _Devto_Forem_Session=083abe58d5e6933fa1c90551d...
# 2004  _Devto_Forem_Session=083abe58d5e6933fa1c90551d...
# 2005  _Devto_Forem_Session=083abe58d5e6933fa1c90551d...
# 2006  _Devto_Forem_Session=083abe58d5e6933fa1c90551d...
# 2007  _Devto_Forem_Session=083abe58d5e6933fa1c90551d...
#
# [2008 rows x 116 columns]

# %%
url_df = adv.url_to_df(crawl_df["url"])
url_df.to_csv("../output/url_data_devto.csv")

# %%
url_d = crawl_df["url"]
url_d = url_d.to_json(orient="index")
url_d
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[18], line 2
#       1 url_d = crawl_df["url"]
# ----> 2 url_d = url_d.to_json(orient="index",name="url")
#       3 url_d
#
# TypeError: to_json() got an unexpected keyword argument 'name'

# %%
files = os.listdir("../output")
files = ["../output/"+file for file in files if file.endswith(".csv")]
files
# Out:
# ['../output/url_data.csv',
#  '../output/url_data_ahrefs.csv',
#  '../output/url_data_devto.csv',
#  '../output/url_data_medium.csv']

# %%
## To load dataframes with all files ending in csv based on above created path
df = pd.concat(
    map(pd.read_csv, files), ignore_index=True)
df
# Out:
#       Unnamed: 0                                                url scheme  \
# 0              0  https://zeo.org/resources/blog/basic-seo-data-...  https
# 1              1  https://zeo.org/tr/kaynaklar/blog/python-ile-s...  https
# 2              2                              https://zeo.org/hello  https
# 3              3                 https://zeo.org/tools/serp-preview  https
# 4              4    https://zeo.org/tools/chrome-extensions-for-seo  https
# ...          ...                                                ...    ...
# 7016        1792  https://medium.com/scribe/the-illusion-of-time...  https
# 7017        1793  https://medium.com/@aknott21?source=collection...  https
# 7018        1794  https://medium.com/tag/cannes-film-festival?so...  https
# 7019        1795           https://medium.com/@sionann.mastromonico  https
# 7020        1796                        https://alunaya.medium.com/  https
#
#                   netloc                                               path  \
# 0                zeo.org  /resources/blog/basic-seo-data-analysis-with-p...
# 1                zeo.org          /tr/kaynaklar/blog/python-ile-seo-analizi
# 2                zeo.org                                             /hello
# 3                zeo.org                                /tools/serp-preview
# 4                zeo.org                   /tools/chrome-extensions-for-seo
# ...                  ...                                                ...
# 7016          medium.com          /scribe/the-illusion-of-time-1202e0ea075b
# 7017          medium.com                                         /@aknott21
# 7018          medium.com                          /tag/cannes-film-festival
# 7019          medium.com                             /@sionann.mastromonico
# 7020  alunaya.medium.com                                                  /
#
#                                                   query fragment  \
# 0                                                   NaN      NaN
# 1                                                   NaN      NaN
# 2                                                   NaN      NaN
# 3                                                   NaN      NaN
# 4                                                   NaN      NaN
# ...                                                 ...      ...
# 7016  source=user_profile---------7-----------------...      NaN
# 7017                          source=collection-archive      NaN
# 7018  source=user_profile--------------------cannes_...      NaN
# 7019                                                NaN      NaN
# 7020                                                NaN      NaN
#
#                       dir_1                              dir_2  \
# 0                 resources                               blog
# 1                        tr                          kaynaklar
# 2                     hello                                NaN
# 3                     tools                       serp-preview
# 4                     tools          chrome-extensions-for-seo
# ...                     ...                                ...
# 7016                 scribe  the-illusion-of-time-1202e0ea075b
# 7017              @aknott21                                NaN
# 7018                    tag               cannes-film-festival
# 7019  @sionann.mastromonico                                NaN
# 7020                    NaN                                NaN
#
#                                     dir_3  ... query_client_id query_scope  \
# 0     basic-seo-data-analysis-with-python  ...             NaN         NaN
# 1                                    blog  ...             NaN         NaN
# 2                                     NaN  ...             NaN         NaN
# 3                                     NaN  ...             NaN         NaN
# 4                                     NaN  ...             NaN         NaN
# ...                                   ...  ...             ...         ...
# 7016                                  NaN  ...             NaN         NaN
# 7017                                  NaN  ...             NaN         NaN
# 7018                                  NaN  ...             NaN         NaN
# 7019                                  NaN  ...             NaN         NaN
# 7020                                  NaN  ...             NaN         NaN
#
#      query_exclude-homepages query_one-article-per-domain query_mtm_campaign  \
# 0                        NaN                          NaN                NaN
# 1                        NaN                          NaN                NaN
# 2                        NaN                          NaN                NaN
# 3                        NaN                          NaN                NaN
# 4                        NaN                          NaN                NaN
# ...                      ...                          ...                ...
# 7016                     NaN                          NaN                NaN
# 7017                     NaN                          NaN                NaN
# 7018                     NaN                          NaN                NaN
# 7019                     NaN                          NaN                NaN
# 7020                     NaN                          NaN                NaN
#
#      query_comments_sort                                       query_source  \
# 0                    NaN                                                NaN
# 1                    NaN                                                NaN
# 2                    NaN                                                NaN
# 3                    NaN                                                NaN
# 4                    NaN                                                NaN
# ...                  ...                                                ...
# 7016                 NaN  user_profile---------7------------------------...
# 7017                 NaN                                 collection-archive
# 7018                 NaN  user_profile--------------------cannes_film_fe...
# 7019                 NaN                                                NaN
# 7020                 NaN                                                NaN
#
#      query_responsesOpen query_sortBy query_autoplay
# 0                    NaN          NaN            NaN
# 1                    NaN          NaN            NaN
# 2                    NaN          NaN            NaN
# 3                    NaN          NaN            NaN
# 4                    NaN          NaN            NaN
# ...                  ...          ...            ...
# 7016                 NaN          NaN            NaN
# 7017                 NaN          NaN            NaN
# 7018                 NaN          NaN            NaN
# 7019                 NaN          NaN            NaN
# 7020                 NaN          NaN            NaN
#
# [7021 rows x 50 columns]

# %%
import pandas as pd
import numpy as np
import re
import matplotlib.pyplot as plt
import seaborn as sns
color = sns.color_palette()
from tqdm import tqdm
from urllib.parse import urlparse
pd.set_option("display.max_colwidth", 200)
import warnings
warnings.filterwarnings('ignore')
from sklearn.pipeline import FeatureUnion
from sklearn.model_selection import cross_val_predict, GroupKFold
from sklearn.pipeline import FeatureUnion
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import f1_score, confusion_matrix
from sklearn.linear_model import LogisticRegression
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.naive_bayes import BernoulliNB, ComplementNB, MultinomialNB
from sklearn.ensemble import RandomForestClassifier
from scipy.sparse import hstack
# %matplotlib inline
