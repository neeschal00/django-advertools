# %%
import advertools as adv

import re
from collections import Counter
from wordcloud import WordCloud
stopwords = adv.stopwords
import pandas as pd

# %%
import nltk

from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.probability import FreqDist

nltk.download('punkt')
nltk.download('stopwords')
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\thesm\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\thesm\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\thesm\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# True

# %%
custom_settings = {
    "USER_AGENT": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3",
    "LOG_FILE": "output_file.log"
}
# Crawl site pages
pages = adv.crawl('https://zeo.org/resources/blog/basic-seo-data-analysis-with-python#h_18626418222141665414320013', output_file="seo_crawler.jl",follow_links=True,custom_settings=custom_settings)

# %%
pages = pd.read_json("seo_crawler.jl",lines=True)
pages
# Out:
#                                                     url  \
# 0                              https://pythonspeed.com/
# 1                              https://pythonspeed.com/
# 2     https://zeo.org/resources/blog/basic-seo-data-...
# 3                    https://zeo.org/tools/serp-preview
# 4                                  https://zeo.org/team
# ...                                                 ...
# 1204                   https://zeo.org/resources/blog/2
# 1205  https://zeo.org/resources/e-books/2023-home-fu...
# 1206      https://zeo.org/tr/seo-sozlugu/301-durum-kodu
# 1207  https://zeo.org/tr/kaynaklar/rehberler/content...
# 1208  https://zeo.org/resources/e-books/2023-beauty-...
#
#                                                   title  \
# 0     Write faster Python code, and ship your code f...
# 1     Write faster Python code, and ship your code f...
# 2             Basic SEO Data Analysis With Python | Zeo
# 3              SERP Preview Tool to Simulate SERP | Zeo
# 4                                            Team | Zeo
# ...                                                 ...
# 1204      Digital Marketing and SEO Blog - Page 2 | Zeo
# 1205          2023 Home & Furniture Sector Report | Zeo
# 1206                               301 Durum Kodu | Zeo
# 1207  Content Brief Generator (İçerik Briefi Hazırla...
# 1208    2023 Beauty & Personal Care Sector Report | Zeo
#
#                                               meta_desc  \
# 0     Helping you deploy with confidence, ship highe...
# 1     Helping you deploy with confidence, ship highe...
# 2     Here, you will find basic Python codes in orde...
# 3                                                   NaN
# 4     Who is behind Zeo Agency? Let's find out from ...
# ...                                                 ...
# 1204                                                NaN
# 1205  In this report, we have analyzed the Home & Fu...
# 1206  Bir web sayfasının kalıcı olarak yönlendirildi...
# 1207                                                NaN
# 1208  We share with you our comprehensive 2023 digit...
#
#                                                viewport  \
# 0                 width=device-width, initial-scale=1.0
# 1                 width=device-width, initial-scale=1.0
# 2     width=device-width, initial-scale=1, shrink-to...
# 3     width=device-width, initial-scale=1, shrink-to...
# 4     width=device-width, initial-scale=1, shrink-to...
# ...                                                 ...
# 1204  width=device-width, initial-scale=1, shrink-to...
# 1205  width=device-width, initial-scale=1, shrink-to...
# 1206  width=device-width, initial-scale=1, shrink-to...
# 1207  width=device-width, initial-scale=1, shrink-to...
# 1208  width=device-width, initial-scale=1, shrink-to...
#
#                                                      h1  \
# 0     Write faster Python code, and ship your code f...
# 1     Write faster Python code, and ship your code f...
# 2                   Basic SEO Data Analysis With Python
# 3                                                   NaN
# 4                                        Meet our team!
# ...                                                 ...
# 1204                     Digital Marketing and SEO Blog
# 1205                2023 Home & Furniture Sector Report
# 1206                                     301 Durum Kodu
# 1207  Content Brief Generator (İçerik Briefi Hazırla...
# 1208          2023 Beauty & Personal Care Sector Report
#
#                                                      h2  \
# 0     Faster and more memory efficient data science@...
# 1     Faster and more memory efficient data science@...
# 2     Importing Libraries@@Basic Codes to Analyze Cr...
# 3     SERP Preview Tool@@Get the best of Zeo news st...
# 4      Get the best of Zeo news straight to your inbox!
# ...                                                 ...
# 1204   Get the best of Zeo news straight to your inbox!
# 1205  Content of the Report@@Get the best of Zeo new...
# 1206  En güncel gelişmeleri takip etmek için bülteni...
# 1207  Content Brief Generator Nedir?@@Content Brief ...
# 1208  Challenges in the industry@@Opportunities in t...
#
#                                                      h3  \
# 0     Learn practical Python software engineering sk...
# 1     Learn practical Python software engineering sk...
# 2                  Contact us@@London@@İstanbul@@Ankara
# 3     Why should I use the SERP Preview tool?@@Conta...
# 4                  Contact us@@London@@İstanbul@@Ankara
# ...                                                 ...
# 1204               Contact us@@London@@İstanbul@@Ankara
# 1205               Contact us@@London@@İstanbul@@Ankara
# 1206  Otoritelerin Yazıları@@Alakalı Terimler@@Alaka...
# 1207              Bize Ulaşın@@Londra@@İstanbul@@Ankara
# 1208               Contact us@@London@@İstanbul@@Ankara
#
#                      canonical  \
# 0     https://pythonspeed.com/
# 1     https://pythonspeed.com/
# 2                          NaN
# 3                          NaN
# 4                          NaN
# ...                        ...
# 1204                       NaN
# 1205                       NaN
# 1206                       NaN
# 1207                       NaN
# 1208                       NaN
#
#                                                alt_href  \
# 0                                             /atom.xml
# 1                                             /atom.xml
# 2     /tr/feed/articles.xml@@/feed/articles.xml@@/tr...
# 3     /tr/feed/articles.xml@@/feed/articles.xml@@/tr...
# 4     /tr/feed/articles.xml@@/feed/articles.xml@@/tr...
# ...                                                 ...
# 1204  /tr/feed/articles.xml@@/feed/articles.xml@@/tr...
# 1205  /tr/feed/articles.xml@@/feed/articles.xml@@/tr...
# 1206  /tr/feed/articles.xml@@/feed/articles.xml@@/tr...
# 1207  /tr/feed/articles.xml@@/feed/articles.xml@@/tr...
# 1208  /tr/feed/articles.xml@@/feed/articles.xml@@/tr...
#
#                                                og:title  ...  \
# 0     Write faster Python code, and ship your code f...  ...
# 1     Write faster Python code, and ship your code f...  ...
# 2                   Basic SEO Data Analysis With Python  ...
# 3                    SERP Preview Tool to Simulate SERP  ...
# 4                                                  Team  ...
# ...                                                 ...  ...
# 1204            Digital Marketing and SEO Blog - Page 2  ...
# 1205                2023 Home & Furniture Sector Report  ...
# 1206                                     301 Durum Kodu  ...
# 1207  Content Brief Generator (İçerik Briefi Hazırla...  ...
# 1208          2023 Beauty & Personal Care Sector Report  ...
#
#                resp_headers_x-timer resp_headers_x-xss-protection  \
# 0                               NaN                           NaN
# 1                               NaN                           NaN
# 2     S1691506820.696534,VS0,VE1659                 1; mode=block
# 3      S1691506822.808140,VS0,VE889                 1; mode=block
# 4     S1691506822.810972,VS0,VE1052                 1; mode=block
# ...                             ...                           ...
# 1204   S1691506982.399057,VS0,VE320                 1; mode=block
# 1205  S1691506982.780672,VS0,VE1202                 1; mode=block
# 1206  S1691506982.371948,VS0,VE1175                 1; mode=block
# 1207  S1691506983.546052,VS0,VE1257                 1; mode=block
# 1208  S1691506982.981612,VS0,VE2645                 1; mode=block
#
#                                  resp_headers_report-to  \
# 0                                                   NaN
# 1                                                   NaN
# 2     {"endpoints":[{"url":"https:\/\/a.nel.cloudfla...
# 3     {"endpoints":[{"url":"https:\/\/a.nel.cloudfla...
# 4     {"endpoints":[{"url":"https:\/\/a.nel.cloudfla...
# ...                                                 ...
# 1204  {"endpoints":[{"url":"https:\/\/a.nel.cloudfla...
# 1205  {"endpoints":[{"url":"https:\/\/a.nel.cloudfla...
# 1206  {"endpoints":[{"url":"https:\/\/a.nel.cloudfla...
# 1207  {"endpoints":[{"url":"https:\/\/a.nel.cloudfla...
# 1208  {"endpoints":[{"url":"https:\/\/a.nel.cloudfla...
#
#                                        resp_headers_nel resp_headers_alt-svc  \
# 0                                                   NaN                  NaN
# 1                                                   NaN                  NaN
# 2     {"success_fraction":0,"report_to":"cf-nel","ma...  h3=":443"; ma=86400
# 3     {"success_fraction":0,"report_to":"cf-nel","ma...  h3=":443"; ma=86400
# 4     {"success_fraction":0,"report_to":"cf-nel","ma...  h3=":443"; ma=86400
# ...                                                 ...                  ...
# 1204  {"success_fraction":0,"report_to":"cf-nel","ma...  h3=":443"; ma=86400
# 1205  {"success_fraction":0,"report_to":"cf-nel","ma...  h3=":443"; ma=86400
# 1206  {"success_fraction":0,"report_to":"cf-nel","ma...  h3=":443"; ma=86400
# 1207  {"success_fraction":0,"report_to":"cf-nel","ma...  h3=":443"; ma=86400
# 1208  {"success_fraction":0,"report_to":"cf-nel","ma...  h3=":443"; ma=86400
#
#                                  request_headers_cookie  \
# 0                                                   NaN
# 1                                                   NaN
# 2     datadome=2G4NPWNQoLhwSxwT7j~kVeEsu2TJI4xybc~er...
# 3     datadome=396~sKmG2oVsHt8G3nghN7D8ufb0D7g6ui_uR...
# 4     datadome=396~sKmG2oVsHt8G3nghN7D8ufb0D7g6ui_uR...
# ...                                                 ...
# 1204  datadome=6o0Yu12J6iESzz7n5BeulYDuyzvAh_CYmK5X_...
# 1205  datadome=noTHod~wmhMvassAS0mY-ytI6QK1lTawmuajt...
# 1206  datadome=5b4UwM5o-_hPD_LWwxtWpEc49REYjUdopFBmv...
# 1207  datadome=4DhOn6pmlji_PEYP9gScWDXCMjmVyNiE87gf6...
# 1208  datadome=noTHod~wmhMvassAS0mY-ytI6QK1lTawmuajt...
#
#                                 request_headers_referer   h6  \
# 0                                                   NaN  NaN
# 1                                                   NaN  NaN
# 2                                                   NaN  NaN
# 3     https://zeo.org/resources/blog/basic-seo-data-...  NaN
# 4     https://zeo.org/resources/blog/basic-seo-data-...  NaN
# ...                                                 ...  ...
# 1204                     https://zeo.org/resources/blog  NaN
# 1205                  https://zeo.org/resources/e-books  NaN
# 1206          https://zeo.org/tr/seo-sozlugu/teknik-seo  NaN
# 1207  https://zeo.org/tr/kaynaklar/rehberler/kategor...  NaN
# 1208                  https://zeo.org/resources/e-books  NaN
#
#      resp_headers_x-proxy-backend retry_times
# 0                             NaN         NaN
# 1                             NaN         NaN
# 2                             NaN         NaN
# 3                             NaN         NaN
# 4                             NaN         NaN
# ...                           ...         ...
# 1204                          NaN         NaN
# 1205                          NaN         NaN
# 1206                          NaN         1.0
# 1207                          NaN         1.0
# 1208                          NaN         NaN
#
# [1209 rows x 106 columns]

# %%
url_df = adv.url_to_df(pages['url'])
url_df
# Out:
#                                                     url scheme  \
# 0                              https://pythonspeed.com/  https
# 1                              https://pythonspeed.com/  https
# 2     https://zeo.org/resources/blog/basic-seo-data-...  https
# 3                    https://zeo.org/tools/serp-preview  https
# 4                                  https://zeo.org/team  https
# ...                                                 ...    ...
# 1204                   https://zeo.org/resources/blog/2  https
# 1205  https://zeo.org/resources/e-books/2023-home-fu...  https
# 1206      https://zeo.org/tr/seo-sozlugu/301-durum-kodu  https
# 1207  https://zeo.org/tr/kaynaklar/rehberler/content...  https
# 1208  https://zeo.org/resources/e-books/2023-beauty-...  https
#
#                netloc                                               path  \
# 0     pythonspeed.com                                                  /
# 1     pythonspeed.com                                                  /
# 2             zeo.org  /resources/blog/basic-seo-data-analysis-with-p...
# 3             zeo.org                                /tools/serp-preview
# 4             zeo.org                                              /team
# ...               ...                                                ...
# 1204          zeo.org                                  /resources/blog/2
# 1205          zeo.org  /resources/e-books/2023-home-furniture-sector-...
# 1206          zeo.org                     /tr/seo-sozlugu/301-durum-kodu
# 1207          zeo.org  /tr/kaynaklar/rehberler/content-brief-generato...
# 1208          zeo.org  /resources/e-books/2023-beauty-personal-care-s...
#
#      query                      fragment      dir_1         dir_2  \
# 0      NaN                           NaN        NaN           NaN
# 1      NaN                           NaN        NaN           NaN
# 2      NaN  h_18626418222141665414320013  resources          blog
# 3      NaN                           NaN      tools  serp-preview
# 4      NaN                           NaN       team           NaN
# ...    ...                           ...        ...           ...
# 1204   NaN                           NaN  resources          blog
# 1205   NaN                           NaN  resources       e-books
# 1206   NaN                           NaN         tr   seo-sozlugu
# 1207   NaN                           NaN         tr     kaynaklar
# 1208   NaN                           NaN  resources       e-books
#
#                                         dir_3  \
# 0                                         NaN
# 1                                         NaN
# 2         basic-seo-data-analysis-with-python
# 3                                         NaN
# 4                                         NaN
# ...                                       ...
# 1204                                        2
# 1205        2023-home-furniture-sector-report
# 1206                           301-durum-kodu
# 1207                                rehberler
# 1208  2023-beauty-personal-care-sector-report
#
#                                                   dir_4 dir_5 dir_6  \
# 0                                                   NaN   NaN   NaN
# 1                                                   NaN   NaN   NaN
# 2                                                   NaN   NaN   NaN
# 3                                                   NaN   NaN   NaN
# 4                                                   NaN   NaN   NaN
# ...                                                 ...   ...   ...
# 1204                                                NaN   NaN   NaN
# 1205                                                NaN   NaN   NaN
# 1206                                                NaN   NaN   NaN
# 1207  content-brief-generator-icerik-briefi-hazirlam...   NaN   NaN
# 1208                                                NaN   NaN   NaN
#
#                                                last_dir query_utm_source  \
# 0                                                   NaN              NaN
# 1                                                   NaN              NaN
# 2                   basic-seo-data-analysis-with-python              NaN
# 3                                          serp-preview              NaN
# 4                                                  team              NaN
# ...                                                 ...              ...
# 1204                                                  2              NaN
# 1205                  2023-home-furniture-sector-report              NaN
# 1206                                     301-durum-kodu              NaN
# 1207  content-brief-generator-icerik-briefi-hazirlam...              NaN
# 1208            2023-beauty-personal-care-sector-report              NaN
#
#      query_utm_medium query_utm_campaign
# 0                 NaN                NaN
# 1                 NaN                NaN
# 2                 NaN                NaN
# 3                 NaN                NaN
# 4                 NaN                NaN
# ...               ...                ...
# 1204              NaN                NaN
# 1205              NaN                NaN
# 1206              NaN                NaN
# 1207              NaN                NaN
# 1208              NaN                NaN
#
# [1209 rows x 16 columns]

# %%
# Extract info from URLs
url_df = adv.url_to_df(pages['url'])
url_df['page_type'] = classify_page_type(url_df['path'])

# %%
# Check robots.txt
robots_df = adv.robotstxt_to_df('https://www.pythonspeed.com/robots.txt')
robots_df
# Out:
# 2023-08-07 11:56:30,034 | INFO | robotstxt.py:381 | robotstxt_to_df | Getting: https://www.pythonspeed.com/robots.txt
#     directive                              content  \
# 0  User-agent                                    *
# 1       Allow                                    /
# 2    Disallow                            /atom.xml
# 3     Sitemap  https://pythonspeed.com/sitemap.xml
#
#                                      etag                       robotstxt_url  \
# 0  "960b5beb46fbba859b494d4e0d886956-ssl"  https://pythonspeed.com/robots.txt
# 1  "960b5beb46fbba859b494d4e0d886956-ssl"  https://pythonspeed.com/robots.txt
# 2  "960b5beb46fbba859b494d4e0d886956-ssl"  https://pythonspeed.com/robots.txt
# 3  "960b5beb46fbba859b494d4e0d886956-ssl"  https://pythonspeed.com/robots.txt
#
#                      download_date
# 0 2023-08-07 15:56:30.431032+00:00
# 1 2023-08-07 15:56:30.431032+00:00
# 2 2023-08-07 15:56:30.431032+00:00
# 3 2023-08-07 15:56:30.431032+00:00

# %%
test_df = adv.robotstxt_test(robotstxt_url="https://www.pythonspeed.com/robots.txt", user_agents=['Googlebot'],
urls=pages['url'])
test_df
# Out:
#                             robotstxt_url user_agent  \
# 0  https://www.pythonspeed.com/robots.txt  Googlebot
#
#                    url_path  can_fetch
# 0  https://pythonspeed.com/       True

# %%
blocked_pages = test_df[test_df['can_fetch'] == False]
blocked_pages
# Out:
# Empty DataFrame
# Columns: [robotstxt_url, user_agent, url_path, can_fetch]
# Index: []

# %%
# Review sitemap
sitemap_df = adv.sitemap_to_df('https://pythonspeed.com/sitemap.xml')
sitemap_df
# Out:
# 2023-08-07 11:57:14,295 | INFO | sitemaps.py:536 | sitemap_to_df | Getting https://pythonspeed.com/sitemap.xml
#                                                    loc  \
# 0    https://pythonspeed.com/articles/python-multip...
# 1     https://pythonspeed.com/articles/verified-fakes/
# 2             https://pythonspeed.com/articles/pylint/
# 3    https://pythonspeed.com/articles/slow-tests-fa...
# 4    https://pythonspeed.com/articles/slow-ci-aws-ec2/
# ..                                                 ...
# 176            https://pythonspeed.com/pycon20/slides/
# 177           https://pythonspeed.com/pydata19/slides/
# 178         https://pythonspeed.com/pydata2022/slides/
# 179        https://pythonspeed.com/pydatapittsburgh23/
# 180         https://pythonspeed.com/pygotham19/slides/
#
#                       lastmod                              sitemap  \
# 0   2023-02-17 19:56:40+00:00  https://pythonspeed.com/sitemap.xml
# 1   2021-10-01 15:00:09+00:00  https://pythonspeed.com/sitemap.xml
# 2   2023-05-01 19:36:22+00:00  https://pythonspeed.com/sitemap.xml
# 3   2021-10-01 15:00:09+00:00  https://pythonspeed.com/sitemap.xml
# 4   2021-10-01 15:00:09+00:00  https://pythonspeed.com/sitemap.xml
# ..                        ...                                  ...
# 176 2023-07-12 21:23:49+00:00  https://pythonspeed.com/sitemap.xml
# 177 2023-07-12 21:23:49+00:00  https://pythonspeed.com/sitemap.xml
# 178 2023-07-12 21:23:49+00:00  https://pythonspeed.com/sitemap.xml
# 179 2023-07-12 21:23:49+00:00  https://pythonspeed.com/sitemap.xml
# 180 2023-07-12 21:23:49+00:00  https://pythonspeed.com/sitemap.xml
#
#                                        etag  sitemap_size_mb  \
# 0    "e0b57fe88740087bb8743f5fecca33e0-ssl"         0.021605
# 1    "e0b57fe88740087bb8743f5fecca33e0-ssl"         0.021605
# 2    "e0b57fe88740087bb8743f5fecca33e0-ssl"         0.021605
# 3    "e0b57fe88740087bb8743f5fecca33e0-ssl"         0.021605
# 4    "e0b57fe88740087bb8743f5fecca33e0-ssl"         0.021605
# ..                                      ...              ...
# 176  "e0b57fe88740087bb8743f5fecca33e0-ssl"         0.021605
# 177  "e0b57fe88740087bb8743f5fecca33e0-ssl"         0.021605
# 178  "e0b57fe88740087bb8743f5fecca33e0-ssl"         0.021605
# 179  "e0b57fe88740087bb8743f5fecca33e0-ssl"         0.021605
# 180  "e0b57fe88740087bb8743f5fecca33e0-ssl"         0.021605
#
#                        download_date
# 0   2023-08-07 15:57:14.300954+00:00
# 1   2023-08-07 15:57:14.300954+00:00
# 2   2023-08-07 15:57:14.300954+00:00
# 3   2023-08-07 15:57:14.300954+00:00
# 4   2023-08-07 15:57:14.300954+00:00
# ..                               ...
# 176 2023-08-07 15:57:14.300954+00:00
# 177 2023-08-07 15:57:14.300954+00:00
# 178 2023-08-07 15:57:14.300954+00:00
# 179 2023-08-07 15:57:14.300954+00:00
# 180 2023-08-07 15:57:14.300954+00:00
#
# [181 rows x 6 columns]

# %%
missing_pages = set(sitemap_df['loc']) - set(pages['url'])
missing_pages
# Out:
# {'https://pythonspeed.com/PyGotham2020/',
#  'https://pythonspeed.com/about/',
#  'https://pythonspeed.com/articles/a-better-flamegraph/',
#  'https://pythonspeed.com/articles/activate-conda-dockerfile/',
#  'https://pythonspeed.com/articles/activate-virtualenv-dockerfile/',
#  'https://pythonspeed.com/articles/alpine-docker-python/',
#  'https://pythonspeed.com/articles/base-image-python-docker-images/',
#  'https://pythonspeed.com/articles/best-file-format-for-pandas/',
#  'https://pythonspeed.com/articles/beyond-cprofile/',
#  'https://pythonspeed.com/articles/blocking-cpu-or-io/',
#  'https://pythonspeed.com/articles/build-secrets-docker-compose/',
#  'https://pythonspeed.com/articles/celery-performance/',
#  'https://pythonspeed.com/articles/centos-8-is-dead/',
#  'https://pythonspeed.com/articles/chunking-pandas/',
#  'https://pythonspeed.com/articles/circleci-docker/',
#  'https://pythonspeed.com/articles/concurrency-control/',
#  'https://pythonspeed.com/articles/conda-dependency-management/',
#  'https://pythonspeed.com/articles/conda-docker-image-size/',
#  'https://pythonspeed.com/articles/conda-security-scans/',
#  'https://pythonspeed.com/articles/conda-vs-docker/',
#  'https://pythonspeed.com/articles/conda-vs-pip/',
#  'https://pythonspeed.com/articles/consistent-benchmarking-in-ci/',
#  'https://pythonspeed.com/articles/containers-filesystem-data-processing/',
#  'https://pythonspeed.com/articles/cpu-limits-to-speed/',
#  'https://pythonspeed.com/articles/crash-out-of-memory/',
#  'https://pythonspeed.com/articles/custom-python-profiler/',
#  'https://pythonspeed.com/articles/cython-limitations/',
#  'https://pythonspeed.com/articles/data-doesnt-fit-in-memory/',
#  'https://pythonspeed.com/articles/debugging-docker-build/',
#  'https://pythonspeed.com/articles/developing-tools-for-ops/',
#  'https://pythonspeed.com/articles/disabling-docker-caching/',
#  'https://pythonspeed.com/articles/distributing-software/',
#  'https://pythonspeed.com/articles/do-you-need-cluster-or-multiprocessing/',
#  'https://pythonspeed.com/articles/docker-build-problems-mac/',
#  'https://pythonspeed.com/articles/docker-build-secrets/',
#  'https://pythonspeed.com/articles/docker-buildkit/',
#  'https://pythonspeed.com/articles/docker-cache-insecure-images/',
#  'https://pythonspeed.com/articles/docker-cache-pip-downloads/',
#  'https://pythonspeed.com/articles/docker-caching-model/',
#  'https://pythonspeed.com/articles/docker-connection-refused/',
#  'https://pythonspeed.com/articles/docker-history/',
#  'https://pythonspeed.com/articles/docker-performance-overhead/',
#  'https://pythonspeed.com/articles/docker-python-security-scan/',
#  'https://pythonspeed.com/articles/docker-secret-scanner/',
#  'https://pythonspeed.com/articles/docker-security-scanner/',
#  'https://pythonspeed.com/articles/dockerizing-python-is-hard/',
#  'https://pythonspeed.com/articles/dont-need-kubernetes/',
#  'https://pythonspeed.com/articles/easiest-rust-python/',
#  'https://pythonspeed.com/articles/estimating-memory-usage/',
#  'https://pythonspeed.com/articles/estimating-pandas-memory/',
#  'https://pythonspeed.com/articles/externally-managed-environment-pep-668/',
#  'https://pythonspeed.com/articles/faster-conda-install/',
#  'https://pythonspeed.com/articles/faster-db-tests/',
#  'https://pythonspeed.com/articles/faster-json-library/',
#  'https://pythonspeed.com/articles/faster-multi-stage-builds/',
#  'https://pythonspeed.com/articles/faster-multiprocessing-pickle/',
#  'https://pythonspeed.com/articles/faster-pandas-dask/',
#  'https://pythonspeed.com/articles/faster-pip-installs/',
#  'https://pythonspeed.com/articles/faster-python-json-parsing/',
#  'https://pythonspeed.com/articles/faster-python/',
#  'https://pythonspeed.com/articles/faster-text-processing/',
#  'https://pythonspeed.com/articles/fixing-performance-with-hardware/',
#  'https://pythonspeed.com/articles/float64-float32-precision/',
#  'https://pythonspeed.com/articles/function-calls-prevent-garbage-collection/',
#  'https://pythonspeed.com/articles/gitlab-build-docker-image/',
#  'https://pythonspeed.com/articles/gunicorn-in-docker/',
#  'https://pythonspeed.com/articles/high-cost-slow-docker-builds/',
#  'https://pythonspeed.com/articles/high-cost-slow-tests/',
#  'https://pythonspeed.com/articles/identifying-images/',
#  'https://pythonspeed.com/articles/importerror-docker/',
#  'https://pythonspeed.com/articles/indexing-pandas-sqlite/',
#  'https://pythonspeed.com/articles/json-memory-streaming/',
#  'https://pythonspeed.com/articles/leaking-secrets-docker/',
#  'https://pythonspeed.com/articles/live-debugging-python/',
#  'https://pythonspeed.com/articles/logging-for-scientific-computing/',
#  'https://pythonspeed.com/articles/logging-vs-profiling/',
#  'https://pythonspeed.com/articles/measure-performance-production/',
#  'https://pythonspeed.com/articles/measuring-memory-python/',
#  'https://pythonspeed.com/articles/measuring-python-performance/',
#  'https://pythonspeed.com/articles/memory-profiler-data-scientists/',
#  'https://pythonspeed.com/articles/minimizing-copying/',
#  'https://pythonspeed.com/articles/mmap-vs-zarr-hdf5/',
#  'https://pythonspeed.com/articles/multi-stage-docker-python/',
#  'https://pythonspeed.com/articles/numba-faster-python/',
#  'https://pythonspeed.com/articles/numpy-is-slow/',
#  'https://pythonspeed.com/articles/numpy-memory-footprint/',
#  'https://pythonspeed.com/articles/numpy-memory-views/',
#  'https://pythonspeed.com/articles/official-docker-best-practices/',
#  'https://pythonspeed.com/articles/official-python-docker-image/',
#  'https://pythonspeed.com/articles/old-fashioned-software-optimized/',
#  'https://pythonspeed.com/articles/pandas-dataframe-series-memory-usage/',
#  'https://pythonspeed.com/articles/pandas-load-less-data/',
#  'https://pythonspeed.com/articles/pandas-read-csv-fast/',
#  'https://pythonspeed.com/articles/pandas-reduce-memory-lossy/',
#  'https://pythonspeed.com/articles/pandas-sql-chunking/',
#  'https://pythonspeed.com/articles/pandas-string-dtype-memory/',
#  'https://pythonspeed.com/articles/pandas-vectorization/',
#  'https://pythonspeed.com/articles/parallelism-slower/',
#  'https://pythonspeed.com/articles/performance-memory-locality/',
#  'https://pythonspeed.com/articles/pipenv-docker/',
#  'https://pythonspeed.com/articles/podman-buildkit/',
#  'https://pythonspeed.com/articles/poetry-vs-docker-caching/',
#  'https://pythonspeed.com/articles/polars-exploratory-data-analysis-vs-production/',
#  'https://pythonspeed.com/articles/polars-memory-pandas/',
#  'https://pythonspeed.com/articles/premature-optimization/',
#  'https://pythonspeed.com/articles/programmers-buying-guide/',
#  'https://pythonspeed.com/articles/pylint-flake8-ruff/',
#  'https://pythonspeed.com/articles/pylint/',
#  'https://pythonspeed.com/articles/python-c-extension-crashes/',
#  'https://pythonspeed.com/articles/python-extension-performance/',
#  'https://pythonspeed.com/articles/python-gil/',
#  'https://pythonspeed.com/articles/python-integers-memory/',
#  'https://pythonspeed.com/articles/python-multiprocessing/',
#  'https://pythonspeed.com/articles/python-object-memory/',
#  'https://pythonspeed.com/articles/python-out-of-memory/',
#  'https://pythonspeed.com/articles/python-server-memory-leaks/',
#  'https://pythonspeed.com/articles/reduce-memory-array-copies/',
#  'https://pythonspeed.com/articles/reproducible-docker-builds-python/',
#  'https://pythonspeed.com/articles/root-capabilities-docker-security/',
#  'https://pythonspeed.com/articles/rust-cython-python-extensions/',
#  'https://pythonspeed.com/articles/schema-migrations-server-startup/',
#  'https://pythonspeed.com/articles/security-updates-in-docker/',
#  'https://pythonspeed.com/articles/shell-scripts/',
#  'https://pythonspeed.com/articles/slow-ci-aws-ec2/',
#  'https://pythonspeed.com/articles/slow-data-analysis-tasks/',
#  'https://pythonspeed.com/articles/slow-tests-fast-feedback/',
#  'https://pythonspeed.com/articles/smaller-docker-images/',
#  'https://pythonspeed.com/articles/smaller-python-docker-images/',
#  'https://pythonspeed.com/articles/speed-is-situational/',
#  'https://pythonspeed.com/articles/speeding-up-docker-ci/',
#  'https://pythonspeed.com/articles/speeding-up-numba/',
#  'https://pythonspeed.com/articles/stop-using-python-3.7/',
#  'https://pythonspeed.com/articles/system-packages-docker/',
#  'https://pythonspeed.com/articles/test-your-docker-build/',
#  'https://pythonspeed.com/articles/transgressive-programming/',
#  'https://pythonspeed.com/articles/upgrade-pip/',
#  'https://pythonspeed.com/articles/upgrade-python-3.11/',
#  'https://pythonspeed.com/articles/vectorization-python-alternatives/',
#  'https://pythonspeed.com/articles/vectorization-python/',
#  'https://pythonspeed.com/articles/verified-fakes/',
#  'https://pythonspeed.com/articles/vscode-broken-docker/',
#  'https://pythonspeed.com/articles/when-update-dependencies/',
#  'https://pythonspeed.com/assets/polars-bluebikes/sciagraph_eager/',
#  'https://pythonspeed.com/assets/polars-bluebikes/sciagraph_lazy/',
#  'https://pythonspeed.com/consulting/',
#  'https://pythonspeed.com/datascience/',
#  'https://pythonspeed.com/docker/',
#  'https://pythonspeed.com/europython2020/',
#  'https://pythonspeed.com/europython2020/slides/',
#  'https://pythonspeed.com/europython2021/',
#  'https://pythonspeed.com/europython2021/slides/',
#  'https://pythonspeed.com/fil/',
#  'https://pythonspeed.com/privacypolicy/',
#  'https://pythonspeed.com/products/',
#  'https://pythonspeed.com/products/condacontainer/',
#  'https://pythonspeed.com/products/datascience/',
#  'https://pythonspeed.com/products/docker/',
#  'https://pythonspeed.com/products/dockerprocess/',
#  'https://pythonspeed.com/products/justenoughdockerpackaging/',
#  'https://pythonspeed.com/products/productionhandbook/',
#  'https://pythonspeed.com/products/pythoncontainer/',
#  'https://pythonspeed.com/products/pythoncontainer/LICENSE-1.0/',
#  'https://pythonspeed.com/products/pythoncontainer/LICENSE-1.1/',
#  'https://pythonspeed.com/products/pythoncontainer/LICENSE-1.2/',
#  'https://pythonspeed.com/products/pythoncontainer/LICENSE-2.0/',
#  'https://pythonspeed.com/products/pythoncontainer/documentation.html',
#  'https://pythonspeed.com/pwc2023/',
#  'https://pythonspeed.com/pwc2023/slides.html',
#  'https://pythonspeed.com/pycon20/',
#  'https://pythonspeed.com/pycon20/slides/',
#  'https://pythonspeed.com/pydata19/',
#  'https://pythonspeed.com/pydata19/slides/',
#  'https://pythonspeed.com/pydata2022/',
#  'https://pythonspeed.com/pydata2022/slides/',
#  'https://pythonspeed.com/pydatapittsburgh23/',
#  'https://pythonspeed.com/pygotham19/',
#  'https://pythonspeed.com/pygotham19/slides/',
#  'https://pythonspeed.com/pygotham2020/',
#  'https://pythonspeed.com/terms/',
#  'https://pythonspeed.com/training/'}

# %% [markdown]
# ## Get Keywords Funtion
# The function below that uses regular expression to sort and clean any **numeric values** and **symbols**, also removing the stopwords consisted in the text to get keywords existing in the function which will be used in the application for analytics purposes.

# %%
def extract_keywords(body_text):    
    pattern = r'[^a-zA-Z0-9@\s]'
    body_text = re.sub(pattern,"",body_text)
    numPattern = r'\d+'
    body_text = re.sub(numPattern,"",body_text)
    body_text = re.sub(r'\b\w\b', '', body_text)
    whiteSpacePattern = r'\s+'
    body_text = re.sub(whiteSpacePattern," ",body_text)
    for text in adv.stopwords["english"]:
        body_text = body_text.replace(" "+text.lower()+" "," ")
    keywords = body_text.lower().split(" ")

    return keywords

# %% [markdown]
# ### Get Only Words from the text
# **Words** only with replaced special characters and Numeric values

# %%
def extract_words(text):
    words = re.findall(r'\b\w+\b', text)
    return len(words)

# %% [markdown]
# ### Extract Stopwords or common words from Text

# %%
def extract_stopwords(text):
    stop_words = set(stopwords.words('english'))
    words = text.split()
    stopwords_found = [word for word in words if word.lower() in stop_words]
    return stopwords_found

# %% [markdown]
# ### Text Readability Score of the content in the webpage
#
# Get the text readability score of the content of the webpage using **Flesch-Kincaid Readability Formula** which commonly used. The nltk libraries is used which must be downloaded and set

# %%
def text_readability(text):
    sentences = nltk.sent_tokenize(text)
    words = nltk.word_tokenize(text)
    
    num_sentences = len(sentences)
    num_words = len(words)
    num_syllables = 0
    
    for word in words:
        num_syllables += syllable_count(word)
    
    if num_sentences == 0:
        num_sentences = 1
    
    readability_score = 206.835 - 1.015 * (num_words / num_sentences) - 84.6 * (num_syllables / num_words)
    return readability_score

def syllable_count(word):
    vowels = "AEIOUaeiou"
    syllables = 0
    prev_char = None
    
    for char in word:
        if char in vowels and (prev_char is None or prev_char not in vowels):
            syllables += 1
        prev_char = char
    
    if word.endswith('e'):
        syllables -= 1
    
    if syllables == 0:
        syllables = 1
    
    return syllables

# %%
# Analyze text
pages['word_count'] = pages['body_text'].apply(extract_words)
pages["word_count"]
# Out:
# 0        173
# 1        173
# 2       2044
# 3        204
# 4        344
#         ...
# 1204     274
# 1205     439
# 1206     181
# 1207     621
# 1208     629
# Name: word_count, Length: 1209, dtype: int64

# %%
pages['keywords'] = pages['body_text'].apply(extract_keywords)
pages['keywords']
# Out:
# 0       [articles, learn, speed, code, reduce, memory,...
# 1       [articles, learn, speed, code, reduce, memory,...
# 2       [services, seo, performance, marketing, conten...
# 3       [services, seo, performance, marketing, conten...
# 4       [services, seo, performance, marketing, conten...
#                               ...
# 1204    [services, seo, performance, marketing, conten...
# 1205    [services, seo, performance, marketing, conten...
# 1206    [hizmetler, seo, performans, pazarlamas, erik,...
# 1207    [hizmetler, seo, performans, pazarlamas, erik,...
# 1208    [services, seo, performance, marketing, conten...
# Name: keywords, Length: 1209, dtype: object

# %%
pages['readable'] = pages['body_text'].apply(text_readability)
pages['readable']
# Out:
# 0       65.131731
# 1       65.131731
# 2       70.556201
# 3       46.780794
# 4       10.367461
#           ...
# 1204   -23.115473
# 1205    45.948313
# 1206     8.492308
# 1207     3.670079
# 1208    43.773315
# Name: readable, Length: 1209, dtype: float64

# %%
# Stopwords analysis
pages['common_words'] = pages["body_text"].apply(extract_stopwords)
pages["common_words"]
# Out:
# 0       [how, to, up, your, and, and, to, your, in, yo...
# 1       [how, to, up, your, and, and, to, your, in, yo...
# 2       [About, About, and, With, We, and, because, to...
# 3       [About, About, to, By, the, you, can, the, and...
# 4       [About, About, and, of, We, are, to, have, in,...
#                               ...
# 1204       [About, About, Can, Can, From, and, From, and]
# 1205    [About, About, I, to, We, with, you, our, for,...
# 1206                                                   []
# 1207    [Can, ve, ve, ve, Here, to, This, ve, ve, ve, ...
# 1208    [About, About, I, to, We, with, you, our, for,...
# Name: common_words, Length: 1209, dtype: object

# %%
wordcloud = WordCloud().generate(' '.join(pages['common_words']))
wordcloud.to_file("wordcloud.png")

# %%
pages["title"] = pages["title"].fillna(" ")

# %%
# Metadata checks
pages['title_length'] = pages['title'].apply(len)
pages["title_length"]
# Out:
# 0       51
# 1       51
# 2       41
# 3       40
# 4       10
#         ..
# 1204    45
# 1205    41
# 1206    20
# 1207    79
# 1208    47
# Name: title_length, Length: 1209, dtype: int64

# %%
pages["meta_desc"] = pages["meta_desc"].fillna(" ")
pages['desc_length'] = pages['meta_desc'].apply(len)

# %%
pages['canonical'] = pages['url'] == pages['canonical_link']
